# %%
from typing import List, Dict, Any, Optional
import asyncio
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model="mistral:7b")

messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Explain recursion."}
]


result = llm.invoke(messages)

print("results: ", result.content)
# Out:
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[2], line 9
#       1 llm = ChatOllama(model="mistral:7b")
#       3 messages = [
#       4     {"role": "system", "content": "You are a helpful assistant."},
#       5     {"role": "user", "content": "Explain recursion."}
#       6 ]
# ----> 9 result = llm.invoke(messages)
#      11 print("results: ", result.content)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\language_models\chat_models.py:398, in BaseChatModel.invoke(self, input, config, stop, **kwargs)
#     384 @override
#     385 def invoke(
#     386     self,
#    (...)
#     391     **kwargs: Any,
#     392 ) -> AIMessage:
#     393     config = ensure_config(config)
#     394     return cast(
#     395         "AIMessage",
#     396         cast(
#     397             "ChatGeneration",
# --> 398             self.generate_prompt(
#     399                 [self._convert_input(input)],
#     400                 stop=stop,
#     401                 callbacks=config.get("callbacks"),
#     402                 tags=config.get("tags"),
#     403                 metadata=config.get("metadata"),
#     404                 run_name=config.get("run_name"),
#     405                 run_id=config.pop("run_id", None),
#     406                 **kwargs,
#     407             ).generations[0][0],
#     408         ).message,
#     409     )
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\language_models\chat_models.py:1117, in BaseChatModel.generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1108 @override
#    1109 def generate_prompt(
#    1110     self,
#    (...)
#    1114     **kwargs: Any,
#    1115 ) -> LLMResult:
#    1116     prompt_messages = [p.to_messages() for p in prompts]
# -> 1117     return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\language_models\chat_models.py:927, in BaseChatModel.generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     924 for i, m in enumerate(input_messages):
#     925     try:
#     926         results.append(
# --> 927             self._generate_with_cache(
#     928                 m,
#     929                 stop=stop,
#     930                 run_manager=run_managers[i] if run_managers else None,
#     931                 **kwargs,
#     932             )
#     933         )
#     934     except BaseException as e:
#     935         if run_managers:
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_core\language_models\chat_models.py:1221, in BaseChatModel._generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1219     result = generate_from_stream(iter(chunks))
#    1220 elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1221     result = self._generate(
#    1222         messages, stop=stop, run_manager=run_manager, **kwargs
#    1223     )
#    1224 else:
#    1225     result = self._generate(messages, stop=stop, **kwargs)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_ollama\chat_models.py:1025, in ChatOllama._generate(self, messages, stop, run_manager, **kwargs)
#    1018 def _generate(
#    1019     self,
#    1020     messages: list[BaseMessage],
#    (...)
#    1023     **kwargs: Any,
#    1024 ) -> ChatResult:
# -> 1025     final_chunk = self._chat_stream_with_aggregation(
#    1026         messages, stop, run_manager, verbose=self.verbose, **kwargs
#    1027     )
#    1028     generation_info = final_chunk.generation_info
#    1029     chat_generation = ChatGeneration(
#    1030         message=AIMessage(
#    1031             content=final_chunk.text,
#    (...)
#    1038         generation_info=generation_info,
#    1039     )
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_ollama\chat_models.py:960, in ChatOllama._chat_stream_with_aggregation(self, messages, stop, run_manager, verbose, **kwargs)
#     951 def _chat_stream_with_aggregation(
#     952     self,
#     953     messages: list[BaseMessage],
#    (...)
#     957     **kwargs: Any,
#     958 ) -> ChatGenerationChunk:
#     959     final_chunk = None
# --> 960     for chunk in self._iterate_over_stream(messages, stop, **kwargs):
#     961         if final_chunk is None:
#     962             final_chunk = chunk
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_ollama\chat_models.py:1049, in ChatOllama._iterate_over_stream(self, messages, stop, **kwargs)
#    1042 def _iterate_over_stream(
#    1043     self,
#    1044     messages: list[BaseMessage],
#    1045     stop: list[str] | None = None,
#    1046     **kwargs: Any,
#    1047 ) -> Iterator[ChatGenerationChunk]:
#    1048     reasoning = kwargs.get("reasoning", self.reasoning)
# -> 1049     for stream_resp in self._create_chat_stream(messages, stop, **kwargs):
#    1050         if not isinstance(stream_resp, str):
#    1051             content = (
#    1052                 stream_resp["message"]["content"]
#    1053                 if "message" in stream_resp and "content" in stream_resp["message"]
#    1054                 else ""
#    1055             )
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\langchain_ollama\chat_models.py:947, in ChatOllama._create_chat_stream(self, messages, stop, **kwargs)
#     945 if chat_params["stream"]:
#     946     if self._client:
# --> 947         yield from self._client.chat(**chat_params)
#     948 elif self._client:
#     949     yield self._client.chat(**chat_params)
#
# File c:\Users\DELL\AppData\Local\Programs\Python\Python312\Lib\site-packages\ollama\_client.py:179, in Client._request.<locals>.inner()
#     177 except httpx.HTTPStatusError as e:
#     178   e.response.read()
# --> 179   raise ResponseError(e.response.text, e.response.status_code) from None
#     181 for line in r.iter_lines():
#     182   part = json.loads(line)
#
# ResponseError: llama runner process has terminated: exit status 2 (status code: 500)
